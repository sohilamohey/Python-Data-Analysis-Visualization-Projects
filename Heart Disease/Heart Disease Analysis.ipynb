# %% [markdown]
# <H2>1. Import The Libraries And Dataset

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

# %%
#df = sns.load_dataset("penguins")
#sns.pairplot(df, hue="species")

# %%
data = pd.read_csv('heart.csv')

# %% [markdown]
# <H2>2. Display Top 5 Rows of The Dataset

# %%
print('The first 5 rows of the dataset:')
data.head()
# Out:
# The first 5 rows of the dataset:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# <h2>3. Check The Last 5 Rows of The Dataset

# %%
print("The last 5 rows of the dataset:")
data.tail()
# Out:
# The last 5 rows of the dataset:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# <h2>4. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
print('The shape of dataset:',data.shape)
# Out:
# The shape of dataset: (1025, 14)

# %% [markdown]
# <h2>5. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
x = data.shape
print("Number of rows: {}\nNumber of columns: {}".format(x[0],x[1]))
# Out:
# Number of rows: 1025
# Number of columns: 14

# %%
print('Column      datatype')
data.info()
# Out:
# Column      datatype
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# <h2>6. Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print('True contains number of null values in the column and False contains number of not null values in the column')
missingData = data.isnull()
for column in missingData.columns.values.tolist():
    print('Column name:',column)
    print(missingData[column].value_counts())
    print("****************************************************************")
# Out:
# True contains number of null values in the column and False contains number of not null values in the column
# Column name: age
# False    1025
# Name: age, dtype: int64
# ****************************************************************
# Column name: sex
# False    1025
# Name: sex, dtype: int64
# ****************************************************************
# Column name: cp
# False    1025
# Name: cp, dtype: int64
# ****************************************************************
# Column name: trestbps
# False    1025
# Name: trestbps, dtype: int64
# ****************************************************************
# Column name: chol
# False    1025
# Name: chol, dtype: int64
# ****************************************************************
# Column name: fbs
# False    1025
# Name: fbs, dtype: int64
# ****************************************************************
# Column name: restecg
# False    1025
# Name: restecg, dtype: int64
# ...

# %% [markdown]
# <h2>7. Check For Duplicate Data and Drop Them

# %%
duplicateData = data.duplicated().any()
duplicateData
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
duplicateData = data.duplicated().any()
duplicateData
# Out:
# False

# %% [markdown]
# <h2>8. Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# <h2>9. Draw Correlation Matrix

# %%
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(), annot =True, color = 'black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>10. How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset?

# %%
x = data['target'].value_counts()
print('People have Heart Disease: {}\nPeople do not have Heart Disease: {}'.format(x[0],x[1]))
# Out:
# People have Heart Disease: 138
# People do not have Heart Disease: 164

# %% [markdown]
# <h2>11. Find Count of  Male & Female in this Dataset

# %%
data['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
sns.countplot(data['sex'])
plt.xticks([0,1], ['Female', 'Male'])
plt.show()
# Out:
# c:\Users\sohil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <H2>12. Find Gender Distribution According to The Target Variable

# %%
sns.countplot(x= 'sex', hue = 'target', data = data)
plt.xticks([1,0], ['Male', 'Female'])
plt.legend(labels = ['No-Disease', 'Disease'])
plt.show()

# %% [markdown]
# <h2>13. Check Age Distribution In The Dataset

# %%
sns.distplot(data['age'])
# Out:
# c:\Users\sohil\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# <h2>14. Check Chest Pain Type

# %%
sns.countplot(data['cp'])#,color=['green', 'blue', 'orange','red'])
plt.xticks([0,1,2,3], ['Typical angina', 'Atypical angina', 'non-anginal pain', 'Asymptomatic'])
plt.show()
# Out:
# c:\Users\sohil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <h2>15. Show The Chest Pain Distribution As Per Target Variable

# %%
sns.countplot(x = 'cp', hue = 'target', data = data)
plt.legend(labels = ['No-Disease', 'Disease'])
plt.xticks([0,1,2,3], ['Typical angina', 'Atypical angina', 'non-anginal pain', 'Asymptomatic'])
plt.show()

# %% [markdown]
# <h2 >
# 16. Show Fasting Blood Sugar Distribution According To Target Variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x = 'fbs', hue = 'target', data = data)
plt.legend(labels = ['No-Disease', 'Disease'])
plt.xticks([0,1], ['Female', 'Male'])
plt.show()

# %% [markdown]
# <h2>17.  Check Resting Blood Pressure Distribution

# %%
data['trestbps'].hist(color = 'brown')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>18. Compare Resting Blood Pressure As Per Sex Column

# %%
a = sns.FacetGrid(data, hue = 'sex', aspect =3)
a.map(sns.kdeplot,  'trestbps', shade =True)
plt.legend(labels = ['Male', 'Female'])
plt.show()

# %% [markdown]
# <h2>19. Show Distribution of Serum cholesterol

# %%
data['chol'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>20. Plot Continuous Variables

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
categorical_val = []
continuse_val = []
for column in data.columns:
    if data[column].nunique() <= 10:
        categorical_val.append(column)
    else:
        continuse_val.append(column)

# %%
continuse_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
categorical_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
data.hist(continuse_val, figsize = (14,8))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'trestbps'}>],
#        [<AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'thalach'}>],
#        [<AxesSubplot:title={'center':'oldpeak'}>, <AxesSubplot:>]],
#       dtype=object)
